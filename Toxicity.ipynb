# %% [markdown]
# <a href="https://colab.research.google.com/github/vyom10445/toxicity-classifier/blob/main/Toxicity.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os
import pandas as pd
import tensorflow as tf
import numpy as np

# %%
df = pd.read_csv(
    os.path.join(
        "data",
        "jigsaw-toxic-comment-classification-challenge",
        "train.csv"
    )
)
